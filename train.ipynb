# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
from data.dataset import SplitImageDataset
from models.generator import Generator
from models.discriminator import Discriminator
from utils import generator_loss, discriminator_loss

# %%
EPOCHS = 100
BATCH_SIZE = 8

dataset = SplitImageDataset("data/facades/train")
loader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

device = "cuda" if torch.cuda.is_available() else "cpu"
gen = Generator().to(device)
disc = Discriminator().to(device)

opt_gen = optim.Adam(gen.parameters(), lr=2e-4, betas=(0.5, 0.999))
opt_disc = optim.Adam(disc.parameters(), lr=2e-4, betas=(0.5, 0.999))

for epoch in range(EPOCHS):
    for idx, (corrupted, real) in enumerate(loader):
        corrupted = corrupted.to(device)
        real = real.to(device)

        # ============================
        # Train Discriminator
        # ============================
        fake = gen(corrupted)

        disc_loss = discriminator_loss(
            disc, real, fake, corrupted
        )

        opt_disc.zero_grad()
        disc_loss.backward()
        opt_disc.step()

        # ============================
        # Train Generator
        # ============================
        fake = gen(corrupted)

        gen_loss = generator_loss(
            disc, fake, real, corrupted
        )

        opt_gen.zero_grad()
        gen_loss.backward()
        opt_gen.step()

        if idx % 50 == 0:
            print(
                f"Epoch [{epoch}/{EPOCHS}] "
                f"Batch [{idx}/{len(loader)}] "
                f"D Loss: {disc_loss.item():.4f} "
                f"G Loss: {gen_loss.item():.4f}"
            )
# Out:
# Epoch [0/100] Batch [0/50] D Loss: 0.7211 G Loss: 68.8169
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 43
#      41 opt_gen.zero_grad()
#      42 gen_loss.backward()
# ---> 43 opt_gen.step()
#      45 if idx % 50 == 0:
#      46     print(
#      47         f"Epoch [{epoch}/{EPOCHS}] "
#      48         f"Batch [{idx}/{len(loader)}] "
#      49         f"D Loss: {disc_loss.item():.4f} "
#      50         f"G Loss: {gen_loss.item():.4f}"
#      51     )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\optim\optimizer.py:517, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     512         else:
#     513             raise RuntimeError(
#     514                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     515             )
# --> 517 out = func(*args, **kwargs)
#     518 self._optimizer_step_code()
#     520 # call optimizer step post hooks
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\optim\optimizer.py:82, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      80     torch.set_grad_enabled(self.defaults["differentiable"])
#      81     torch._dynamo.graph_break()
# ---> 82     ret = func(*args, **kwargs)
#      83 finally:
#      84     torch._dynamo.graph_break()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\optim\adam.py:247, in Adam.step(self, closure)
#     235     beta1, beta2 = group["betas"]
#     237     has_complex = self._init_group(
#     238         group,
#     239         params_with_grad,
#    (...)    244         state_steps,
#     245     )
# --> 247     adam(
#     248         params_with_grad,
#     249         grads,
#     250         exp_avgs,
#     251         exp_avg_sqs,
#     252         max_exp_avg_sqs,
#     253         state_steps,
#     254         amsgrad=group["amsgrad"],
#     255         has_complex=has_complex,
#     256         beta1=beta1,
#     257         beta2=beta2,
#     258         lr=group["lr"],
#     259         weight_decay=group["weight_decay"],
#     260         eps=group["eps"],
#     261         maximize=group["maximize"],
#     262         foreach=group["foreach"],
#     263         capturable=group["capturable"],
#     264         differentiable=group["differentiable"],
#     265         fused=group["fused"],
#     266         grad_scale=getattr(self, "grad_scale", None),
#     267         found_inf=getattr(self, "found_inf", None),
#     268         decoupled_weight_decay=group["decoupled_weight_decay"],
#     269     )
#     271 return loss
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\optim\optimizer.py:150, in _disable_dynamo_if_unsupported.<locals>.wrapper.<locals>.maybe_fallback(*args, **kwargs)
#     148     return disabled_func(*args, **kwargs)
#     149 else:
# --> 150     return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\optim\adam.py:953, in adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, foreach, capturable, differentiable, fused, grad_scale, found_inf, has_complex, decoupled_weight_decay, amsgrad, beta1, beta2, lr, weight_decay, eps, maximize)
#     950 else:
#     951     func = _single_tensor_adam
# --> 953 func(
#     954     params,
#     955     grads,
#     956     exp_avgs,
#     957     exp_avg_sqs,
#     958     max_exp_avg_sqs,
#     959     state_steps,
#     960     amsgrad=amsgrad,
#     961     has_complex=has_complex,
#     962     beta1=beta1,
#     963     beta2=beta2,
#     964     lr=lr,
#     965     weight_decay=weight_decay,
#     966     eps=eps,
#     967     maximize=maximize,
#     968     capturable=capturable,
#     969     differentiable=differentiable,
#     970     grad_scale=grad_scale,
#     971     found_inf=found_inf,
#     972     decoupled_weight_decay=decoupled_weight_decay,
#     973 )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\torch\optim\adam.py:466, in _single_tensor_adam(params, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps, grad_scale, found_inf, amsgrad, has_complex, beta1, beta2, lr, weight_decay, eps, maximize, capturable, differentiable, decoupled_weight_decay)
#     462         exp_avg_sq.mul_(beta2).addcmul_(
#     463             grad, grad, value=cast(float, 1 - beta2)
#     464         )
#     465 else:
# --> 466     exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)  # type: ignore[arg-type]
#     468 if capturable or differentiable:
#     469     step = step_t
#
# KeyboardInterrupt:
